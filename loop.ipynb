# %% [markdown]
# <a href="https://colab.research.google.com/github/codewithtarun2005/ATM-simulator/blob/main/loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git config --global user.name "codewithtarun2005"
# !git config --global user.email "tp781396@gmail.com"

# %%
# !git clone https://github.com/codewithtarun2005/python-fundamental.git

# %%
# %cd python-fundamental

# %%
ls

# %%
# !pwd
# !git add .
# !git commit -m "Updated loop notebook"

# %%
for i in range(1,6,2):
  print(i)

# %%
for i in range(2,11):
  print(i)

# %%
for i in range(2,11):
  print(i , end = "  ")

# %%
print(2)
print(1,end= "#")
print(3, end= "$")

# %%
for i in range(5):

 print("hi")

# %%
for i in range(5):
  print(i+1)

# %%
for i in range(10,0,-1):
 print(i)

# %%
for i in range(10):
 print(10 -i)

# %%
for i in range(0,11,2):

 print(i)

# %%
for i in range(6):
  print(2*i)

# %%
for i in range(11):
  if  i % 2 == 0:
    print( i )

# %%
for i in range(1,10,2):

 print(i)

# %%
for i in range(10):
  if i % 2 != 0:
    print(i)

# %%
for i in "tarun":
 print(i)

# %%
for i in "tarun":
  print(i,end = "-")

# %%
name = "tarun"
print("-".join(name))

# %%
for i in range(2,8):

  print(i,"=",i ** 2)

# %%
for i in range(2,8):
  print(i,"=",i*i)

# %%
for i in range(0,51,5):
  print(i)

# %%
for i in range(1,11):
  print(5 , "*",i,"=",i * 82)

# %%
for i in range(1,51):
  if i%5 == 0:
   print(i)

# %%
for i in range(5):
  print(i)

# %%
for i in range(10,0,-2):
  print(i)

# %%
for i in range(2):
  print("hello")
  print("ai")

# %%
for i in range(2):
  print("hello")
  print("ai")

# %%
name = "tarun"
 for i in name:
  if i == "a":
    print(i)

# %% [markdown]
# #while loop
